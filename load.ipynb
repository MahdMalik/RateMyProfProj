# %%
from dotenv import load_dotenv
load_dotenv()
import os
import google.generativeai as genai
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key = os.getenv("PINECONE_PRIVATE_KEY"))
pc.create_index(name = "rag", dimension = 768, metric = "cosine", spec = ServerlessSpec(cloud="aws", region="us-east-1"))

# %%
import json
data = json.load(open("reviews.json"))
data['reviews']
# Out:
# [{'professor': 'Dr. Sarah Chen',
#   'subject': 'Organic Chemistry',
#   'stars': 5,
#   'review': 'Dr. Chen is incredibly passionate about organic chemistry and makes complex concepts easy to understand. Her office hours are super helpful and she genuinely cares about student success.'},
#  {'professor': 'Dr. Michael Rodriguez',
#   'subject': 'World History',
#   'stars': 2,
#   'review': "Lectures are extremely disorganized and the grading seems arbitrary. Often goes off on tangents and doesn't cover the material in the syllabus."},
#  {'professor': 'Dr. Emily Parker',
#   'subject': 'Psychology',
#   'stars': 4,
#   'review': 'Great lecturer who incorporates real-world examples. Only downside is that the workload can be heavy at times.'},
#  {'professor': 'Dr. James Wilson',
#   'subject': 'Calculus II',
#   'stars': 3,
#   'review': "Decent professor but moves through material very quickly. You'll need to do a lot of self-study to keep up with the pace."},
#  {'professor': 'Dr. Lisa Thompson',
#   'subject': 'English Literature',
#   'stars': 5,
#   'review': "Best professor I've had! Her analysis of texts is incredible and she encourages great class discussions. Very fair grader too."},
#  {'professor': 'Dr. Robert Kim',
#   'subject': 'Physics',
#   'stars': 1,
#   'review': 'Seems knowledgeable but terrible at explaining concepts. Rarely responds to emails and is often dismissive of questions in class.'},
#  {'professor': 'Dr. Amanda Foster',
#   'subject': 'Sociology',
#   'stars': 4,
#   'review': 'Really engaging lectures and interesting assignments. Sometimes unclear about expectations for papers but otherwise excellent.'},
#  {'professor': 'Dr. David Martinez',
#   'subject': 'Computer Science',
#   'stars': 5,
#   'review': 'Fantastic instructor who brings real industry experience to the classroom. Projects are challenging but incredibly rewarding.'},
#  {'professor': 'Dr. Jennifer Lee',
#   'subject': 'Biology',
#   'stars': 3,
#   'review': "Lectures are okay but rely too heavily on slides. Lab sessions are well-organized though and she's helpful during them."},
#  {'professor': 'Dr. Thomas Wright',
#   'subject': 'Economics',
#   'stars': 2,
#   'review': 'Very boring lectures and tends to read straight from the textbook. Tests are much harder than the homework assignments.'},
#  {'professor': 'Dr. Rachel Green',
#   'subject': 'Environmental Science',
#   'stars': 5,
#   'review': 'Amazing professor who organizes great field trips and brings in guest speakers. Makes the subject matter really relevant to current issues.'},
#  {'professor': 'Dr. Kevin Chang',
#   'subject': 'Statistics',
#   'stars': 4,
#   'review': 'Clear explanations and provides lots of practice problems. Sometimes gets frustrated when students ask basic questions.'},
#  {'professor': 'Dr. Maria Garcia',
#   'subject': 'Spanish Literature',
#   'stars': 5,
#   'review': 'Incredibly knowledgeable and passionate. Creates a welcoming environment for all language levels and gives great feedback.'},
#  {'professor': 'Dr. William Turner',
#   'subject': 'Philosophy',
#   'stars': 3,
#   'review': 'Interesting perspectives but can be a bit condescending. Participation is a huge part of the grade which can be intimidating.'},
#  {'professor': 'Dr. Patricia Brown',
#   'subject': 'Art History',
#   'stars': 4,
#   'review': 'Very knowledgeable about the subject and shows fascinating examples. Tests are tough but she provides good study guides.'},
#  {'professor': 'Dr. John Anderson',
#   'subject': 'Political Science',
#   'stars': 2,
#   'review': "Clearly biased in his teaching and doesn't encourage different viewpoints in discussions. Assignments are poorly explained."},
#  {'professor': 'Dr. Michelle Taylor',
#   'subject': 'Music Theory',
#   'stars': 5,
#   'review': 'Exceptional at breaking down complex concepts. Always available for extra help and provides great practical exercises.'},
#  {'professor': 'Dr. Richard Harris',
#   'subject': 'Marketing',
#   'stars': 3,
#   'review': 'Good real-world examples but lectures can be dry. Group projects are well-structured and helpful for learning.'},
#  {'professor': 'Dr. Susan White',
#   'subject': 'Anthropology',
#   'stars': 4,
#   'review': 'Fascinating lectures with lots of field experience to share. Heavy reading load but material is interesting.'},
#  {'professor': 'Dr. Daniel Peters',
#   'subject': 'Chemistry',
#   'stars': 1,
#   'review': 'Extremely difficult to understand and unhelpful during office hours. Tests cover material never discussed in class.'}]

# %%
processed_data = []
genai.configure(api_key=os.getenv("GEMINI_PRIVATE_KEY"))
for review in data['reviews']:
    result = genai.embed_content(
        model = "models/text-embedding-004",
        content= review['review']
    )
    processed_data.append({
        "values": result['embedding'],
        "id": review["professor"],
        "metadata": {
            "review": review["review"],
            "subject": review["subject"],
            "stars": review["stars"]
        }
    })

# %%
processed_data[0]
# Out:
# {'values': [0.05088044,
#   0.032853022,
#   -0.016277155,
#   -0.008316894,
#   0.016696172,
#   -0.0035404807,
#   -0.042140666,
#   0.022877635,
#   -0.023695014,
#   0.0007694691,
#   0.06368652,
#   0.058853596,
#   0.03417103,
#   -0.012147661,
#   0.0010728538,
#   -0.040871944,
#   0.012677943,
#   0.0313555,
#   -0.08878948,
#   0.0013894214,
#   -0.0026911958,
#   -0.032893192,
#   0.024551602,
#   -0.05858321,
#   0.0025707674,
#   0.051163904,
#   -0.012200803,
#   -0.035860952,
#   0.030119477,
#   -0.06586982,
#   0.01933641,
#   0.018213585,
#   -0.083262384,
#   -0.030454338,
#   -0.013339498,
#   0.046274032,
#   0.0273361,
#   -0.013845458,
#   0.049035866,
#   -0.048287537,
#   0.0041243723,
#   -0.009034701,
#   -0.008903714,
#   -0.05291094,
#   -0.024519002,
#   -0.02182696,
#   -0.015059295,
#   0.12055108,
#   -0.030451791,
#   0.09115734,
#   0.046548657,
#   0.018269362,
#   -0.019594822,
#   0.0247185,
#   0.0046560145,
#   0.00010479652,
#   -0.028197793,
#   -0.05037278,
#   0.04253725,
#   -0.03399528,
#   -0.023198694,
#   0.0178449,
#   -0.022798326,
#   -0.09198736,
#   0.06749149,
#   -0.04624813,
#   -0.062124547,
#   -0.060094282,
#   0.005139618,
#   0.014716074,
#   0.046103295,
#   -0.04916018,
#   0.033935666,
#   0.020071207,
#   0.0025006586,
#   -0.046671137,
#   -0.032626446,
#   0.019950079,
#   -0.040014304,
#   0.05038984,
#   -0.013320042,
#   0.0564654,
#   0.11084666,
#   0.0049160975,
#   -0.018727768,
#   0.008727857,
#   -0.010296497,
#   -0.0029646163,
#   -0.05806391,
#   -0.0139232,
#   0.00788933,
#   0.009783056,
#   0.022788515,
#   0.008584161,
#   -0.04554379,
#   -0.022714997,
#   -0.03651412,
#   -0.023090823,
#   0.058087394,
#   0.0774268,
#   0.037591644,
#   0.018306434,
#   -0.044998832,
#   -0.006521446,
#   0.0035647685,
#   0.010727247,
#   0.041689053,
#   0.00052709214,
#   -0.016896367,
#   -0.014091803,
#   -0.023286225,
#   0.0041832873,
#   0.037271347,
#   0.021147406,
#   -0.01595456,
#   0.018422646,
#   -0.04552326,
#   0.04350328,
#   -0.021641603,
#   0.003460902,
#   -0.008251574,
#   0.034624875,
#   -0.014770942,
#   -0.020833869,
#   -0.022530928,
#   0.043804526,
#   -0.039646503,
#   -0.015998978,
#   -0.008324908,
#   -0.02038024,
#   -0.012452741,
#   -0.027245905,
#   -0.0076324237,
#   -0.022571962,
#   -0.005669425,
#   0.02598486,
#   0.10441212,
#   -0.053403072,
#   -0.045056533,
#   -0.027691513,
#   0.03527451,
#   0.0017684236,
#   -0.017864538,
#   -0.058158062,
#   -0.06204757,
#   -0.047397584,
#   0.011313146,
#   -0.037251897,
#   -3.6896006e-05,
#   0.010926714,
#   -0.015729574,
#   -0.05857819,
#   0.031352904,
#   -0.004965571,
#   0.039062146,
#   -0.008610928,
#   -0.023050053,
#   -0.0060816985,
#   0.02711009,
#   -0.03053427,
#   0.05993335,
#   -0.058553934,
#   -0.019256607,
#   0.029645298,
#   0.035326585,
#   -0.08952444,
#   0.022272125,
#   0.021636138,
#   -0.017449642,
#   0.013568259,
#   -0.0058688903,
#   0.014718536,
#   -0.03746755,
#   0.10423618,
#   -0.021215646,
#   0.05012527,
#   0.014965469,
#   0.0077036293,
#   -0.012014448,
#   -0.038565595,
#   0.034700762,
#   -0.02230305,
#   0.090914026,
#   0.010042783,
#   0.040331792,
#   0.013691257,
#   -0.008084645,
#   -0.08758761,
#   -0.026837312,
#   -0.01969348,
#   -0.02214004,
#   -0.013938799,
#   0.063948594,
#   0.035073977,
#   -0.0042174216,
#   0.041485395,
#   -0.005910704,
#   -0.03801897,
#   0.022937043,
#   0.05958496,
#   -0.06645201,
#   -0.026988974,
#   -0.028830018,
#   -0.0074679656,
#   0.04419333,
#   0.001499367,
#   -0.020300671,
#   0.009453535,
#   0.0044766003,
#   0.03654765,
#   0.008330403,
#   0.039611228,
#   0.039489314,
#   -0.07265075,
#   -0.011117509,
#   -0.054849338,
#   0.05224819,
#   0.01596768,
#   -0.021568516,
#   0.008278461,
#   -0.004687482,
#   -0.039067443,
#   -0.038824208,
#   0.0038436973,
#   -0.00866241,
#   0.002976964,
#   -0.035197783,
#   -0.076785885,
#   -0.0051872884,
#   0.014671135,
#   -0.053166427,
#   -0.019243386,
#   0.044441137,
#   -0.0074427593,
#   -0.03483095,
#   -0.003859611,
#   -0.026952697,
#   -0.082438886,
#   -0.021232422,
#   0.021727169,
#   -0.02272889,
#   0.08071345,
#   -0.021030016,
#   0.02800055,
#   0.037440035,
#   0.0035480235,
#   0.00010400353,
#   -0.044204142,
#   0.030622939,
#   -0.00942383,
#   -0.0023466474,
#   0.009700072,
#   0.012868706,
#   0.046296224,
#   0.020062141],
#  'id': 'Dr. Sarah Chen',
#  'metadata': {'review': 'Dr. Chen is incredibly passionate about organic chemistry and makes complex concepts easy to understand. Her office hours are super helpful and she genuinely cares about student success.',
#   'subject': 'Organic Chemistry',
#   'stars': 5}}

# %%
index = pc.Index('rag')
index.upsert(
    vectors=processed_data,
    namespace="ns1"
)
# Out:
# {'upserted_count': 20}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 20}},
#  'total_vector_count': 20}
